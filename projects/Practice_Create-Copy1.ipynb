# %% [markdown]
# #### Practice AP Performance Task: Create
# ## Solves the problem of deciding what to make for dinner
# ### by Sami Pratt

# %%
def done():
    """prints at the end of the alogirthm
    """
    print("This all sounds delicious. Enjoy your meal!")    
def hamburger():
    """prints how to make a hamburger
    """
    print("Make a hamburger! You'll need ground beef, a bun, lettuce, cheese, and a tomato.")
def fries():
    """prints how to make fries
    """
    print("All you'll need to make fries is some potatoes, oil, salt, pepper, and an oven!")
def lemonade():
    """prints how to make lemonade
    """
    print("I think a nice glass of lemonade would pair splendidly with your meal. Grab yourself some lemons, water, sugar, and ice!")
def ice_cream():
    """prints where to get ice cream
    """
    print("I suggest some classic vanilla ice cream. The ingredients include cream, sugar, vanilla extract, and ice.")
def mac():
    """prints how to make mac 'n' cheese
    """
    print("Looks like you should cook up some mac 'n' cheese. This american great will simply require macaroni noodles and melted cheese.")
def taco():
    """prints how to make a taco
    """
    print("Grab yourself some ground beef, lettuce, cheese, and salsa and place it all in a tortilla.")
def enchilada():
    """prints how to make a chicken enchilada
    """
    print("This enchilada requires chicken, tortillas, canned enchilada sauce, and cheese.")
def chips_guac():
    """prints how to make chips and guacamole
    """
    print("Make it easy on yourself! Go to the store and purchase a bag of tortilla chips and prepared guacamole to save you some time.")
def horchata():
    """prints how to make horchata
    """
    print("A cool glass of horchata is a perfect fit for your meal. You'll need rice, water, and cinammon sticks!")
def flan():
    """prints how to make flan
    """
    print("Flan is a little harder to make, but it is worth it! The ingredients include sweetened condensed milk, eggs, and sugar.")
def dumplings():
    """prints how to make dumplings
    """
    print("Boil some dumpling dough right now! How simple! You just need flour, water, salt, baking powder, and oil.")
def chow_mein():
    """prints how to make chow mein
    """
    print("Noodles, sauce, and cabbage... time to make chow mein!")
def fried_rice():
    """prints how to make fried rice
    """
    print("Now this is one of my favorites. To make fried rice, you need rice, peas, corn, and eggs. ")
def tea():
    """prints how to make tea
    """
    print("A cup of tea should pair well with your meal. Heat up some water in a mug and steep a bag of tea.")
def cookie():
    """prints how to make fortune cookies
    """
    print("You should make some fortune cookies! You'll need to make dough, but don't forget to print out a secret message to put inside!")
def pizza():
    """prints how to make pizza
    """
    print("Pizza party! Put together some pizza dough, red sauce, mozarella, and any toppings of your choice!")
def spaghetti():
    """prints how to make spaghetti
    """
    print("It's spaghetti time! Boil some noodles, roll up some meatballs, and mix it all together with a nice marinara sauce.")
def garlic_bread():
    """prints how to make garlic bread
    """
    print("Purchase a loaf of italian bread at the store and then put some garlic on it. Simple!")
def italian_soda():
    """suggests italian soda as a drink"""
    print("Italian soda is just what you need to fizz up your meal right now!")
def tiramisu():
    """prints how to make tiramisu
    """
    print("Nothing beats a decadent slice of tiramisu after an italian meal. You'll need lady fingers, mascarpone cream, and espresso.")

# %%
def american0():
    """prompts sides and then american2"""
    c = input("Do you want any fries on the side? Yes or no?\n")
    if c == "Yes":
        fries()
        american2()
    elif c == "No":
        american2()
def american1():
    """either ends algorithm or suggests a dessert and then ends algorithm
    """
    e = input("Is that all you want?\n")
    if e == "Yes":
        done()
    elif e == "No":
        f = input("Would you like a dessert? Yes or no?")
        if f == "Yes":
            ice_cream()
            done()
        elif f == "No":
            done()
def american2():
    """suggests a drink option or skips to american1
    """
    d = input("Do you want something to drink? Yes or no?\n")
    if d == "Yes":
        lemonade()
        american1()
    elif d == "No":
        american1()

def mexican0():
    """same function as american0"""
    c = input("Do you want any chips and guacamole on the side? Yes or no?\n")
    if c == "Yes":
        chips_guac()
        mexican2()
    elif c == "No":
        mexican2()
def mexican1():
    """same function as american1"""
    e = input("Is that all you want?\n")
    if e == "Yes":
        done()
    elif e == "No":
        f = input("Would you like a dessert? Yes or no?")
        if f == "Yes":
            flan()
            done()
        elif f == "No":
            done()
def mexican2():
    """same function as american2"""
    d = input("Do you want something to drink? Yes or no?\n")
    if d == "Yes":
        horchata()
        mexican1()
    elif d == "No":
        mexican1()
        
def chinese0():
    """same function as american0"""
    c = input("Do you want any fried rice on the side? Yes or no?\n")
    if c == "Yes":
        fried_rice()
        chinese2()
    elif c == "No":
        chinese2()
def chinese1():
    """same function as american1"""
    e = input("Is that all you want?\n")
    if e == "Yes":
        done()
    elif e == "No":
        f = input("Would you like a dessert? Yes or no?")
        if f == "Yes":
            cookie()
            done()
        elif f == "No":
            done()
def chinese2():
    """same function as american2"""
    d = input("Do you want something to drink? Yes or no?\n")
    if d == "Yes":
        tea()
        chinese1()
    elif d == "No":
        chinese1()
        
def italian0():
    """same function as american0"""
    c = input("Do you want any garlic bread on the side? Yes or no?\n")
    if c == "Yes":
        garlic_bread()
        italian2()
    elif c == "No":
        italian2()
def italian1():
    """same function as american1"""
    e = input("Is that all you want?\n")
    if e == "Yes":
        done()
    elif e == "No":
        f = input("Would you like a dessert? Yes or no?")
        if f == "Yes":
            tiramisu()
            done()
        elif f == "No":
            done()
def italian2():
    """same function as american2"""
    d = input("Do you want something to drink? Yes or no?\n")
    if d == "Yes":
        italian_soda()
        italian1()
    elif d == "No":
        italian1()
          
def switch():
    print("I'm all out of options. Maybe you should try another cuisine.")
    a = input("What cuisine are you craving right now? American? Mexican? Chinese? Italian? Or Surprise?\n")

# %%
# LISTS
americanA = [hamburger(), fries(), lemonade(), ice_cream()]
mexicanA = [taco(), chips_guac(), horchata(), flan()]
chineseA = [dumplings(), fried_rice(), tea(), cookie()]
italianA = [pizza(), garlic_bread(), italian_soda(), tiramisu()]
americanB = [mac(), fries(), lemonade(), ice_cream()]
mexicanB = [enchilada(), chips_guac(), horchata(), flan()]
chineseB = [chow_mein(), fried_rice(), tea(), cookie()]
italianB = [spaghetti(), garlic_bread(), italian_soda(), tiramisu()]
# Out:
# Make a hamburger! You'll need ground beef, a bun, lettuce, cheese, and a tomato.
# All you'll need to make fries is some potatoes, oil, salt, pepper, and an oven!
# I think a nice glass of lemonade would pair splendidly with your meal. Grab yourself some lemons, water, sugar, and ice!
# I suggest some classic vanilla ice cream. The ingredients include cream, sugar, vanilla extract, and ice.
# Grab yourself some ground beef, lettuce, cheese, and salsa and place it all in a tortilla.
# Make it easy on yourself! Go to the store and purchase a bag of tortilla chips and prepared guacamole to save you some time.
# A cool glass of horchata is a perfect fit for your meal. You'll need rice, water, and cinammon sticks!
# Flan is a little harder to make, but it is worth it! The ingredients include sweetened condensed milk, eggs, and sugar.
# Boil some dumpling dough right now! How simple! You just need flour, water, salt, baking powder, and oil.
# ...

# %%
def dinner():
    """Helps decide what you should make for dinner based on your current cravings.
    """
    print("Hello! Welcome to the Dinner Algorithm. I will help you decide what to make for dinner tonight!")
    print("Quick tip: Make sure you capitalize the first letter of all of your inputs.")
    a = input("What cuisine are you craving right now? American? Mexican? Chinese? Italian? Mediterranean? Or Surprise?\n")
    if a == "American":
        b = input("Do feel like a hamburger? Yes or no?\n")
        if b == "Yes":
            hamburger()
            american0()
        elif b == "No":
            g = input("How do you feel about mac 'n' cheese? Yes (you like it) or no?\n")
            if g == "Yes":
                mac()
                american0()
            elif g == "No":
                switch()
    elif a == "Mexican":
        b = input("Do you feel like a taco? Yes or no?")
        if b == "Yes":
            taco()
            mexican0()
        elif b == "No":
            g = input("Would you prefer a chicken enchilada? Yes or no?")
            if g == "Yes":
                enchilada()
                mexican0()
            elif g == "No":
                switch()
    elif a == "Chinese":
        b = input("Do you feel like dumplings tonight? Yes or no?")
        if b == "Yes":
            dumplings()
            chinese0()
        elif b == "No":
            g = input("Does kung pao chicken sound better? Yes or no?")
            if g == "Yes":
                chow_mein()
                chinese0()
            elif g == "No":
                switch()
    elif a == "Italian":
        b = input("Do you think a yummy pizza will satisfy your cravings? Yes or no?")
        if b == "Yes":
            pizza()
            italian0()
        elif b == "No":
            g = input("Maybe spaghetti and meatballs will better suit your needs? Yes or no?")
            if g == "Yes":
                spaghetti()
                italian0()
            elif g == "No":
                switch()
    elif a == "Surprise":
        h = input("Pick a number between 1 and 8.\n")
        if h == "1":
            americanA = [hamburger(), fries(), lemonade(), ice_cream()] 
            done()
        elif h == "2":
            mexicanA = [taco(), chips_guac(), horchata(), flan()]
            done()
        elif h == "3":
            chineseA = [dumplings(), fried_rice(), tea(), cookie()]
            done()
        elif h == "4":
            italianA = [pizza(), garlic_bread(), italian_soda(), tiramisu()]
            done()
        elif h == "5":
            americanB = [mac(), fries(), lemonade(), ice_cream()]
            done()
        elif h == "6":
            mexicanB = [enchilada(), chips_guac(), horchata(), flan()]
            done()
        elif h == "7":
            chineseB = [chow_mein(), fried_rice(), tea(), cookie()]
            done()
        elif h == "8":
            italianB = [spaghetti(), garlic_bread(), italian_soda(), tiramisu()]
            done()

# %%
dinner()
# Out:
# Hello! Welcome to the Dinner Algorithm. I will help you decide what to make for dinner tonight!
# Quick tip: Make sure you capitalize the first letter of all of your inputs.
